# %%
import h5py
import numpy as np

PATH = "/Users/leopoldomorante/Desktop/vision_galaxiesML/DESI_HSC_64x64_v2.hdf5"
OUTPUT = "DESI_HSC_mini2.npz"
N_MUESTRAS = 35000

with h5py.File(PATH, "r") as f:
    images = f["image"][:N_MUESTRAS]
    # wave = f["spectrum/wave"][:]
    # flux = f["spectrum/flux"][:]

np.savez_compressed(
    OUTPUT,
    images=images,
    # wave=wave,
    # flux=flux
)

print(f"Saved {OUTPUT}")
print(f"Images: {images.shape}")
# print(f"Wave:   {wave.shape}")
# print(f"Flux:   {flux.shape}")
# Out:
# Saved DESI_HSC_mini2.npz
# Images: (35000, 5, 64, 64)
